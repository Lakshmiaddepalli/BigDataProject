# %%
import geocoder
import time
import csv
from geopy import geocoders
from geopy.geocoders import GoogleV3

# %%
ofile  = open('311final.csv', "w")
writer = csv.writer(ofile)

# %%
i = 0
YOUR_API_KEY =  "AIzaSyD2v_0UftOba5BQyt5WY19cjAFdiu9S7FQ"
g = GoogleV3(api_key=YOUR_API_KEY)
with open('311_Service_Requests_-_Vacant_and_Abandoned_Buildings_Reported_-_Historical.csv', mode='r') as infile:
    reader = csv.reader(infile)
    rowval = next(reader)
    writer.writerow(rowval)
    for row in reader:
        val = row[2].split("/")[2]
        #print(val)
        if((row[20]== "" or row[21] == "") and (((len(val) == 4 and int(val) >= 2010) and (len(val)== 4 and int(val) <= 2011)) or ((len(val) == 2 and int(val) >= 10) and (len(val)== 2 and int(val) <= 11)))):
            print(val)
            print(row[20])
            print(row[21])
            address = row[10] + " " + row[11] + " " + row[12] + " " + row[13]
            i = i+1
            print(i)
            print(address)
            time.sleep(0.2)
            location = g.geocode(address + " Chicago",timeout=100000)
            row[20] = location.latitude
            row[21] = location.longitude
            print(location.latitude)
            print(location.longitude)
        writer.writerow(row)
# Out:
# 2011
#
#
# 1
# 7100 S YATES BLVD
# 41.7662004
# -87.5665238
# 2011
#
#
# 2
# 5138 S MOZART ST
# 41.7997889
# -87.6955289
# 2011
#
#
# 3
# 6715 S CLARMONT ST
# 41.7714038
# -87.6818241
# 2011
#
#
# 4
# 8557 S BUFFALO AVE
# 41.739913
# -87.54361279999999
# 2011
#
#
# 5
# 6951 S LOWE  AND UNION AVE
# 41.76738
# -87.6405192
# 2011
#
#
# 6
# 11810 S PEORIA ST
# 41.679162
# -87.64473699999999
# 2011
#
#
# 7
# 8015 S PRINCETON AVE
# 41.7484671
# -87.63153659999999
# 2011
#
#
# 8
# 817 W 49TH PL
# 41.8040806
# -87.64622399999999
# 2011
#
#
# 9
# 1330 W 72ND ST
# 41.7633585
# -87.6585947
# 2011
#
#
# 10
# 12442 S PARNELL AVE
# 41.6675038
# -87.63577749999999
# 2011
#
#
# 11
# 10613 S PERRY AVE
# 41.7012205
# -87.625483
# 2011
#
#
# 12
# 9351 S PERRY AVE
# 41.723858
# -87.625947
# 2011
#
#
# 13
# 5750 S WASHTENAW AVE
# 41.78857
# -87.69156
# 2011
#
#
# 14
# 908 W CHICAGO AVE
# 41.8965003
# -87.65021240000002
# 2011
#
#
# 15
# 4015 W 59TH PL
# 41.7848896
# -87.7228507
# 2010
#
#
# 16
# ...

# %%
ofile.close()
infile.close()

# %%
import csv
import json
from geopy import geocoders
from geopy.geocoders import GoogleV3
import time
import sys

# %%
ofile  = open('311_final.csv', "w")
writer = csv.writer(ofile)

# %%
with open('311final.csv', mode='r') as infile:
    reader = csv.reader(infile)
    rowval = next(reader)
    writer.writerow(rowval)
    for row in reader:
        val1 = row[2].split("/")[2]
        if((row[19]== "") and (((len(val) == 4 and int(val) >= 2010) and (len(val)== 4 and int(val) <= 2011)) or ((len(val) == 2 and int(val) >= 10) and (len(val)== 2 and int(val) <= 11)))):
            #print(row)
            min_distance = sys.maxsize
            with open('communitymappinggeocodemapping.csv', mode='r') as tempfile:
                reader1 = csv.reader(tempfile)  
                rowval = next(reader1)
                for row1 in reader1:
                    print(float(row[20]))
                    print(float(row[21]))
                    val = ((float(row1[2]) - float(row[20]))*(float(row1[2]) - float(row[20])) + (float(row1[3]) - float(row[21]))*(float(row1[3]) - float(row[21])))
                    if(val < min_distance):
                        min_distance = val
                        row[19] = row1[0]
                        print(row[19])
        writer.writerow(row)

# %%
ofile.close()
