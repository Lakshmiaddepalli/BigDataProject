# %%
import geocoder
import time
import csv
from geopy import geocoders
from geopy.geocoders import GoogleV3

# %%
ofile  = open('crimesfinal.csv', "w")
writer = csv.writer(ofile)

# %%
i = 0
YOUR_API_KEY =  "AIzaSyD2v_0UftOba5BQyt5WY19cjAFdiu9S7FQ"
g = GoogleV3(api_key=YOUR_API_KEY)
with open('Crimes_-_2001_to_present.csv', mode='r') as infile:
    reader = csv.reader(infile)
    rowval = next(reader)
    writer.writerow(rowval)
    for row in reader:
        val = row[2].split(" ")[0].split("/")[2]
        #print(val)
        if((row[19]== "" or row[20] == "") and (((len(val) == 4 and int(val) >= 2010) and (len(val)== 4 and int(val) <= 2011)) or ((len(val) == 2 and int(val) >= 10) and (len(val)== 2 and int(val) <= 11)))):
            #print(row)
            print(row[19])
            print(row[20])
            address = " ".join(row[3].split(" ", 1)[1:])
            i = i+1
            print(i)
            print(address)
            time.sleep(0.2)
            location = g.geocode(address + " Chicago",timeout=100000)
            row[19] = location.latitude
            row[20] = location.longitude
            print(location.latitude)
            print(location.longitude)
        writer.writerow(row)

# %%
ofile.close()
infile.close()

# %%
import csv
import json
from geopy import geocoders
from geopy.geocoders import GoogleV3
import time
import sys

# %%
ofile  = open('crimefinal.csv', "w")
writer = csv.writer(ofile)

# %%
with open('crimesfinal.csv', mode='r') as infile:
    reader = csv.reader(infile)
    rowval = next(reader)
    writer.writerow(rowval)
    for row in reader:
        #print(row[2])
        val1 = row[2].split(" ")[0].split("/")[2]
        if((row[13] == "") and (((len(val1) == 4 and int(val1) >= 2010) and (len(val1)== 4 and int(val1) <= 2011)) or ((len(val1) == 2 and int(val1) >= 10) and (len(val1)== 2 and int(val1) <= 11)))):
            #print(row)
            min_distance = sys.maxsize
            with open('communitymappinggeocodemapping.csv', mode='r') as tempfile:
                reader1 = csv.reader(tempfile)  
                rowval = next(reader1)
                for row1 in reader1:
                    val = ((float(row1[2]) - float(row[19]))*(float(row1[2]) - float(row[19])) + (float(row1[3]) - float(row[20]))*(float(row1[3]) - float(row[20])))
                    if(val < min_distance):
                        min_distance = val
                        row[13] = row1[0]
                        print(row[13])
        writer.writerow(row)
# Out:
# 1
# 2
# 5
# 7
# 19
# 22
# 23
# 26
# 27
# 1
# 2
# 9
# 76
# 1
# 2
# 5
# 7
# 8
# 32
# 1
# 2
# 5
# 7
# 8
# 32
# 1
# 2
# 5
# 7
# 22
# 23
# 27
# 1
# 2
# 5
# 7
# 8
# 32
# 1
# 2
# 5
# 7
# 8
# 32
# 1
# 2
# 5
# 7
# 8
# 32
# 1
# 2
# 5
# 7
# 8
# 32
# 1
# 2
# 5
# 7
# 8
# 32
# 1
# 2
# 3
# 6
# 1
# 2
# 3
# 6
# 1
# 2
# 5
# 7
# 19
# 22
# 23
# 26
# 27
# 1
# 2
# 5
# 7
# 8
# 32
# 1
# 2
# 5
# 7
# 8
# 28
# 31
# 32
# 33
# 1
# 1
# 2
# 5
# 7
# 8
# 24
# 28
# 1
# 2
# 5
# 7
# 8
# 24
# 27
# 28
# 29
# 30
# 31
# 34
# 37
# 42
# 67
# 68
# 69
# 71
# 1
# 2
# 5
# 7
# 8
# 32
# 1
# 2
# 5
# 7
# 8
# 28
# 31
# 33
# 34
# 1
# 2
# 5
# 7
# 8
# 24
# 28
# 1
# 2
# 5
# 7
# 19
# 22
# 23
# 26
# 27
# 1
# 2
# 5
# 7
# 8
# 28
# 31
# 33
# 34
# 1
# 2
# 5
# 7
# 8
# 24
# 27
# 28
# 29
# 30
# 31
# 34
# 37
# 42
# 48
# 51
# 53
# 75
# 1
# 2
# 5
# 7
# 8
# 31
# 32
# 33
# 1
# 2
# 5
# 7
# 8
# 24
# 27
# 28
# 29
# 30
# 31
# 34
# 37
# 42
# 67
# 68
# 69
# 71
# 1
# 2
# 5
# 7
# 8
# 24
# 27
# 28
# 29
# 30
# 31
# 34
# 37
# 42
# 48
# 51
# 53
# 75
# 1
# 2
# 5
# ...

# %%
ofile.close()
