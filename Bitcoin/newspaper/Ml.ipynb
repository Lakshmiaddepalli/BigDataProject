# %%
# !pip install feedparser
# !pip install newspaper3k
# Out:
# Requirement already satisfied: feedparser in /Users/lakshmigauri/anaconda3/lib/python3.7/site-packages (5.2.1)
# Requirement already satisfied: newspaper3k in /Users/lakshmigauri/anaconda3/lib/python3.7/site-packages (0.2.8)
# Requirement already satisfied: tldextract>=2.0.1 in /Users/lakshmigauri/anaconda3/lib/python3.7/site-packages (from newspaper3k) (2.2.1)
# Requirement already satisfied: Pillow>=3.3.0 in /Users/lakshmigauri/anaconda3/lib/python3.7/site-packages (from newspaper3k) (5.3.0)
# Requirement already satisfied: lxml>=3.6.0 in /Users/lakshmigauri/anaconda3/lib/python3.7/site-packages (from newspaper3k) (4.2.5)
# Requirement already satisfied: tinysegmenter==0.3 in /Users/lakshmigauri/anaconda3/lib/python3.7/site-packages (from newspaper3k) (0.3)
# Requirement already satisfied: python-dateutil>=2.5.3 in /Users/lakshmigauri/anaconda3/lib/python3.7/site-packages (from newspaper3k) (2.7.5)
# Requirement already satisfied: cssselect>=0.9.2 in /Users/lakshmigauri/anaconda3/lib/python3.7/site-packages (from newspaper3k) (1.0.3)
# Requirement already satisfied: feedfinder2>=0.0.4 in /Users/lakshmigauri/anaconda3/lib/python3.7/site-packages (from newspaper3k) (0.0.4)
# Requirement already satisfied: beautifulsoup4>=4.4.1 in /Users/lakshmigauri/anaconda3/lib/python3.7/site-packages (from newspaper3k) (4.6.3)
# Requirement already satisfied: feedparser>=5.2.1 in /Users/lakshmigauri/anaconda3/lib/python3.7/site-packages (from newspaper3k) (5.2.1)
# Requirement already satisfied: PyYAML>=3.11 in /Users/lakshmigauri/anaconda3/lib/python3.7/site-packages (from newspaper3k) (3.13)
# Requirement already satisfied: nltk>=3.2.1 in /Users/lakshmigauri/anaconda3/lib/python3.7/site-packages (from newspaper3k) (3.4)
# Requirement already satisfied: jieba3k>=0.35.1 in /Users/lakshmigauri/anaconda3/lib/python3.7/site-packages (from newspaper3k) (0.35.1)
# Requirement already satisfied: requests>=2.10.0 in /Users/lakshmigauri/anaconda3/lib/python3.7/site-packages (from newspaper3k) (2.21.0)
# Requirement already satisfied: requests-file>=1.4 in /Users/lakshmigauri/anaconda3/lib/python3.7/site-packages (from tldextract>=2.0.1->newspaper3k) (1.4.3)
# Requirement already satisfied: idna in /Users/lakshmigauri/anaconda3/lib/python3.7/site-packages (from tldextract>=2.0.1->newspaper3k) (2.8)
# Requirement already satisfied: setuptools in /Users/lakshmigauri/anaconda3/lib/python3.7/site-packages (from tldextract>=2.0.1->newspaper3k) (40.6.3)
# Requirement already satisfied: six>=1.5 in /Users/lakshmigauri/anaconda3/lib/python3.7/site-packages (from python-dateutil>=2.5.3->newspaper3k) (1.12.0)
# Requirement already satisfied: singledispatch in /Users/lakshmigauri/anaconda3/lib/python3.7/site-packages (from nltk>=3.2.1->newspaper3k) (3.4.0.3)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /Users/lakshmigauri/anaconda3/lib/python3.7/site-packages (from requests>=2.10.0->newspaper3k) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/lakshmigauri/anaconda3/lib/python3.7/site-packages (from requests>=2.10.0->newspaper3k) (2018.11.29)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /Users/lakshmigauri/anaconda3/lib/python3.7/site-packages (from requests>=2.10.0->newspaper3k) (1.24.1)

# %%
import feedparser as fp
import numpy as np
import json
import newspaper
from newspaper import Article
from time import mktime
from datetime import datetime
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import csv

# %%
# Set the limit for number of articles to download
LIMIT = 1000000000
articles_array = []

data = {}
data['newspapers'] = {}

# Loads the JSON files with news sites
with open('NewsPaper.json') as data_file:
    companies = json.load(data_file)

# %%
count = 1

# Iterate through each news company
for company, value in companies.items():
    # If a RSS link is provided in the JSON file, this will be the first choice.
    # Reason for this is that, RSS feeds often give more consistent and correct data. RSS (Rich Site Summary; originally RDF Site Summary; often called Really Simple Syndication) is a type of
    # web feed which allows users to access updates to online content in a standardized, computer-readable format
    # If you do not want to scrape from the RSS-feed, just leave the RSS attr empty in the JSON file.
    if 'rss' in value:
        d = fp.parse(value['rss'])
        print("Downloading articles from ", company)
        newsPaper = {
            "rss": value['rss'],
            "link": value['link'],
            "articles": []
        }
        for entry in d.entries:
            # Check if publish date is provided, if no the article is skipped.
            # This is done to keep consistency in the data and to keep the script from crashing.
            if hasattr(entry, 'published'):
                if count > LIMIT:
                    break
                article = {}
                article['link'] = entry.link
                date = entry.published_parsed
                article['published'] = datetime.fromtimestamp(mktime(date)).isoformat()
                try:
                    content = Article(entry.link)
                    content.download()
                    content.parse()
                except Exception as e:
                    # If the download for some reason fails (ex. 404) the script will continue downloading
                    # the next article.
                    print(e)
                    print("continuing...")
                    continue
                article['title'] = content.title
                article['text'] = content.text
                article['authors'] = content.authors
                article['top_image'] =  content.top_image
                article['movies'] = content.movies
                newsPaper['articles'].append(article)
                articles_array.append(article)
                print(count, "articles downloaded from", company, ", url: ", entry.link)
                count = count + 1
    else:
        # This is the fallback method if a RSS-feed link is not provided.
        # It uses the python newspaper library to extract articles
        print("Building site for ", company)
        paper = newspaper.build(value['link'], memoize_articles=False)
        newsPaper = {
            "link": value['link'],
            "articles": []
        }
        noneTypeCount = 0
        for content in paper.articles:
            if count > LIMIT:
                break
            try:
                content.download()
                content.parse()
            except Exception as e:
                print(e)
                print("continuing...")
                continue
            # Again, for consistency, if there is no found publish date the article will be skipped.
            # After 10 downloaded articles from the same newspaper without publish date, the company will be skipped.

            article = {}
            article['title'] = content.title
            article['authors'] = content.authors
            article['text'] = content.text
            article['top_image'] =  content.top_image
            article['movies'] = content.movies
            article['link'] = content.url
            article['published'] = content.publish_date
            newsPaper['articles'].append(article)
            articles_array.append(article)
            print(count, "articles downloaded from", company, " using newspaper, url: ", content.url)
            count = count + 1
            #noneTypeCount = 0
    count = 1
    data['newspapers'][company] = newsPaper
# Out:
# Building site for  cnn
# 1 articles downloaded from cnn  using newspaper, url:  https://bitcoinist.com/every-exchange-should-delist-bitcoin-sv-on-may-1st-says-anthony-pompliano/
# 2 articles downloaded from cnn  using newspaper, url:  https://bitcoinist.com/julian-assange-20k-bitcoin-donations-wikileaks/
# 3 articles downloaded from cnn  using newspaper, url:  https://bitcoinist.com/bitcoin-cash-abc-vs-bitcoin-cash-sv-examining-the-bitcoin-cash-hash-war/
# 4 articles downloaded from cnn  using newspaper, url:  https://bitcoinist.com/bitcoin-mining-everything-you-need-to-know/
# 5 articles downloaded from cnn  using newspaper, url:  https://bitcoinist.com/category/news/
# 6 articles downloaded from cnn  using newspaper, url:  https://bitcoinist.com/gbtc-premium-rises-47-above-bitcoin-price-signalling-institutional-demand/
# 7 articles downloaded from cnn  using newspaper, url:  https://bitcoinist.com/bitcoin-dapp-startup-blockstack-files-for-50m-token-offering-with-sec/
# 8 articles downloaded from cnn  using newspaper, url:  https://bitcoinist.com/bitcoin-may-see-sustained-stabilization-in-current-range/
# 9 articles downloaded from cnn  using newspaper, url:  https://bitcoinist.com/bullish-sign-bitcoin-price-misery-index-flashes-3-year-high/
# 10 articles downloaded from cnn  using newspaper, url:  https://www.bitstarz.com/landing/welcome-package-special-offer-btc-jokerizer?refer=Bitcoinist
# 11 articles downloaded from cnn  using newspaper, url:  https://bitcoinist.com/trading-ideas-the-most-powerful-affiliate-marketing-tool/
# 12 articles downloaded from cnn  using newspaper, url:  https://bitcoinist.com/did-the-fed-just-move-bitcoin/
# 13 articles downloaded from cnn  using newspaper, url:  https://bitcoinist.com/23-24-april-singapore-hosts-blockchain-life-2019-a-global-forum-on-blockchain-and-cryptocurrencies/
# 14 articles downloaded from cnn  using newspaper, url:  https://bitcoinist.com/watch-live-spacex-is-launching-epic-triple-landing-attempt/
# 15 articles downloaded from cnn  using newspaper, url:  https://bitcoinist.com/results-of-crypto-event-in-the-czech-republic-blockchain-bitcoin-conference-prague-what-did-speakers-discuss/
# 16 articles downloaded from cnn  using newspaper, url:  https://bitcoinist.com/baer-chain-founder-vincent-the-virtuous-circle-of-mep-ecology-drives-brc-to-climb/
# 17 articles downloaded from cnn  using newspaper, url:  https://bitcoinist.com/how-to-trade-double-tops-and-bottoms/
# 18 articles downloaded from cnn  using newspaper, url:  https://bitcoinist.com/bitcoin-is-more-popular-than-the-spacex-launch-and-elon-musk/
# 19 articles downloaded from cnn  using newspaper, url:  https://bitcoinist.com/how-to-become-a-better-bitcoin-trader-interview/
# 20 articles downloaded from cnn  using newspaper, url:  https://bitcoinist.com/bitcoin-price-falters-5000-support-critical/
# 21 articles downloaded from cnn  using newspaper, url:  https://bitcoinist.com/4-reasons-to-be-bullish-on-bitcoin-and-altcoins-according-to-brian-kelly/
# 22 articles downloaded from cnn  using newspaper, url:  https://bitcoinist.com/high-bitcoin-fees-only-way-to-stay-trustless-says-seoul-meetup-founder/

# %%
#Finally it saves the articles as a CSV-file.
try:
    f = csv.writer(open('Scraped_data_news_output.csv', 'w', encoding='utf-8'))
    f.writerow(['Title', 'Authors','Text','Image','Videos','Link','Published_Date'])
    #print(article)
    for artist_name in articles_array:
        title = artist_name['title']
        authors=artist_name['authors']
        text=artist_name['text']
        image=artist_name['top_image']
        video=artist_name['movies']
        link=artist_name['link']
        publish_date=artist_name['published']
        # Add each artist’s name and associated link to a row
        f.writerow([title, authors, text, image, video, link, publish_date])
except Exception as e: print(e)
